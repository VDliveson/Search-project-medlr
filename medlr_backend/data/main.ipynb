# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv',engine='python')
df.head()
# Out:
#     id                                      Medicine_Link  \
# 0  1.0  https://www.netmeds.com/prescriptions/amilift-...
# 1  2.0  https://pharmeasy.in/online-medicine-order/ami...
# 2  3.0  https://pharmeasy.in/online-medicine-order/ami...
# 3  4.0  https://www.1mg.com/drugs/amilift-dx-12.5-mg-5...
# 4  5.0  https://pharmeasy.in/online-medicine-order/ami...
#
#               Manufacturer  Real_Price  \
# 0    Bion Therapeutics (i)       24.19
# 1        Bion Therapeutics         NaN
# 2        Bion Therapeutics         NaN
# 3  Bion Therapeutics India       25.00
# 4        Bion Therapeutics         NaN
#
#                                              Salts Discounted_Price  \
# 0                              amitriptyline 25 mg            19.84
# 1                           Amitriptyline(25.0 Mg)             25.5
# 2                 Amitriptyline + Chlordiazepoxide            21.25
# 3  Amitriptyline (12.5mg) + Chlordiazepoxide (5mg)              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49037 entries, 0 to 49036
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20000 non-null  float64
#  1   Medicine_Link          20000 non-null  object
#  2   Manufacturer           18804 non-null  object
#  3   Real_Price             16955 non-null  float64
#  4   Salts                  18196 non-null  object
#  5   Discounted_Price       14792 non-null  object
#  6   Quantity_text          17745 non-null  object
#  7   Prescription_Required  20000 non-null  float64
#  8   Medicine_Name          20000 non-null  object
#  9   Packaging              17078 non-null  object
#  10  Quantity               17218 non-null  object
#  11  Form                   19469 non-null  object
#  12  Salt_Len               19221 non-null  float64
#  13  Source                 20000 non-null  object
# ...

# %%
res = df.to_json(orient='records')
